# %% [markdown]
# <center><h1>Instrucciones para el Proyecto Final</h1></center>
# <center><h3>IBM SkillsBuild Europa - Análisis de datos</h3></center>
#
#
#
# # Requisitos:
#
#
# * Tener conocimiento de Python.
# * Tener conocimiento sobre el manejo de datos.
# * Tener conocimiento sobre la visualización de datos.
#
#
# #### Nivel del ejercicio: Intermedio
#
# #### Tiempo de trabajo: 3 horas

# %% [markdown]
# ### Análisis de datos de Airbnb
#
# #### Objetivo:
#
# En este ejercicio, realizarás un análisis de datos con <i>datasets</i> de Airbnb abiertos al público.
# Algunas de las tareas que llevarás a cabo son:
#
#    * limpieza de datos,
#    * transformación de datos y
#    * visualización de datos.
#
# #### Información sobre los datos de Airbnb:
# <p>Cuando visita lugares nuevos busca cubrir dos necesidades principales, tener alojamiento y comida a precios
# razonables. Airbnb (Air-Bed-Breakfast) es un mercado en línea que ha creado un lucrativo modelo de
# negocio basado en una de estas necesidades. La aplicación permite que las personas que tienen una habitación extra
# la alquilen, parcial o totalmente y a corto plazo, a aquellos que buscan un lugar económico para alojarse,
# pues este servicio suele tener un precio relativamente menor que el de los hoteles. Además, personas de
# todo el mundo prefieren el servicio hogareño y económico.
# Propietarios de todo el mundo alquilan su espacio a través de Airbnb a turistas y otros tipos de
# visitantes</p>
#
# #### Fuente del conjunto de datos
# La fuente de este <i>dataset</i> es: <a href="https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata">https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata</a>.
#
# Este <i>dataset</i> contiene información tal como la zona en la cual se ofrecen los servicios, el tipo de
# habitación, el precio, la disponibilidad, las reseñas de otros clientes, el cargo por servicio, la política de
# cancelación y las reglas de la casa. Este análisis ayudará a LetItGo Holiday Consultants a mejorar sus
# servicios para poder ofrecer alojamiento en Airbnb a sus clientes cuando sea pertinente y a colaborar con
# Airbnb para mejorar sus productos y servicios.
#
# ¡Les deseamos lo mejor en su análisis de los datos de Airbnb!

# %% [markdown]
# <h2>Importa las bibliotecas necesarias</h2>

# %%
import pandas as pd
import numpy as np
#  Es requisito importar las bibliotecas de visualización.

# %% [markdown]
# ## Tarea 1: Carga de los datos
#
# * Realiza las siguientes tareas:
#
#    * Lee el archivo csv y conviértelo en un <i>dataframe</i>.
#    * Muestra las primeras cinco filas del <i>dataframe</i>.
#    * Muestra el tipo de datos de cada columna.

# %%
 ## Lee el archivo csv.
df = pd.read_csv('Airbnb_Open_Data.csv', low_memory = False)

# %%
### Muestra las primeras 5 filas.
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
## Muestra los tipos de datos.
df.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# house_rules                        object
# license                            object
# dtype: object

# %% [markdown]
# ## Tarea 2a: Limpieza de los datos
#
# Elimina del dataframe las columnas con los títulos <i>«host id», «id», «country» y «country code»</i>.
# Indica por qué no se incluyen estas columnas en tu análisis de datos.

# %%
## Elimina las columnas no deseadas.
df = df.drop(columns = ['host id' , 'id','country', 'country code'])

# %% [markdown]
# # Tarea 2b: Limpieza de los datos.
#
# * Comprueba los valores que faltan en el <i>dataframe</i> y muestra el recuento en forma ascendente.
#    **Si faltan valores, agrégalos según el tipo de datos de las columnas**.
# * Comprueba si hay valores duplicados y elimínalos.
# * Muestra el número total de registros en el <i>dataframe</i> después de haber eliminado los duplicados.

# %%
## Comprueba los valores que faltan y muestra el recuento en forma ascendente
pd.isnull(df)
# Out:
#          NAME  host_identity_verified  host name  neighbourhood group  \
# 0       False                   False      False                False
# 1       False                   False      False                False
# 2       False                    True      False                False
# 3        True                   False      False                False
# 4       False                   False      False                False
# ...       ...                     ...        ...                  ...
# 102594  False                   False      False                False
# 102595  False                   False      False                False
# 102596  False                   False      False                False
# 102597  False                   False      False                False
# 102598  False                   False      False                False
#
#         neighbourhood    lat   long  instant_bookable  cancellation_policy  \
# 0               False  False  False             False                False
# 1               False  False  False             False                False
# 2               False  False  False             False                False
# 3               False  False  False             False                False
# 4               False  False  False             False                False
# ...               ...    ...    ...               ...                  ...
# 102594          False  False  False             False                False
# 102595          False  False  False             False                False
# 102596          False  False  False             False                False
# 102597          False  False  False             False                False
# 102598          False  False  False             False                False
#
#         room type  ...  service fee  minimum nights  number of reviews  \
# 0           False  ...        False           False              False
# 1           False  ...        False           False              False
# 2           False  ...        False           False              False
# 3           False  ...        False           False              False
# 4           False  ...        False           False              False
# ...           ...  ...          ...             ...                ...
# 102594      False  ...        False           False              False
# 102595      False  ...        False           False              False
# 102596      False  ...        False           False              False
# 102597      False  ...        False           False              False
# 102598      False  ...        False           False              False
#
#         last review  reviews per month  review rate number  \
# 0             False              False               False
# 1             False              False               False
# 2              True               True               False
# 3             False              False               False
# 4             False              False               False
# ...             ...                ...                 ...
# 102594         True               True               False
# 102595        False              False               False
# 102596         True               True               False
# 102597        False              False               False
# 102598         True               True               False
#
#         calculated host listings count  availability 365  house_rules  license
# 0                                False             False        False     True
# 1                                False             False        False     True
# 2                                False             False        False     True
# 3                                False             False         True     True
# 4                                False             False        False     True
# ...                                ...               ...          ...      ...
# 102594                           False             False        False     True
# 102595                           False             False        False     True
# 102596                           False             False         True     True
# 102597                           False             False         True     True
# 102598                           False             False         True     True
#
# [102599 rows x 22 columns]

# %%
## Comprueba si hay valores duplicados y elimínalos.
df = df.drop_duplicates()

# %%
## Muestra el número total de registros después de haber eliminado los duplicados.
df.shape
# Out:
# (99163, 22)

# %% [markdown]
# ## Tarea 3: Transformación de los datos:
#
#
# * Cambia el nombre de la columna <i>«availability 365»</i> por <i>«days_booked»</i>.
# * Convierte los títulos de todas las columnas a minúsculas y cambia los espacios que separan palabras por un guion bajo (_).
# * Elimina el signo de dólares ($) y la coma de las columnas <i>«price»</i> y <i>«service_fee»</i> y conviértelas al tipo de dato que les corresponda.

# %%
## Cambia el nombre de la columna.
df.rename(columns = {'availability 365':'days_booked'})
# Out:
#                                                     NAME  \
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                    NaN
# 4       Entire Apt: Spacious Studio/Loft by central park
# ...                                                  ...
# 102053               Cozy bright room near Prospect Park
# 102054         Private Bedroom with Amazing Rooftop View
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056        Room & private bathroom in historic Harlem
# 102057                                   Rosalee Stewart
#
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# 1                    verified     Jenna           Manhattan
# 2                         NaN     Elise           Manhattan
# 3                 unconfirmed     Garry            Brooklyn
# 4                    verified    Lyndon           Manhattan
# ...                       ...       ...                 ...
# 102053            unconfirmed    Mariam            Brooklyn
# 102054               verified      Trey            Brooklyn
# 102055               verified   Michael            Brooklyn
# 102056            unconfirmed   Shireen           Manhattan
# 102057               verified   Stanley           Manhattan
#
#              neighbourhood       lat      long instant_bookable  \
# 0               Kensington  40.64749 -73.97237            False
# 1                  Midtown  40.75362 -73.98377            False
# 2                   Harlem  40.80902 -73.94190             True
# 3             Clinton Hill  40.68514 -73.95976             True
# 4              East Harlem  40.79851 -73.94399            False
# ...                    ...       ...       ...              ...
# 102053            Flatbush  40.64945 -73.96108             True
# 102054            Bushwick  40.69872 -73.92718            False
# 102055  Bedford-Stuyvesant  40.67810 -73.90822             True
# 102056              Harlem  40.81248 -73.94317             True
# 102057              Harlem  40.81315 -73.94747            False
#
#        cancellation_policy        room type  ...  service fee minimum nights  \
# 0                   strict     Private room  ...        $193            10.0
# 1                 moderate  Entire home/apt  ...         $28            30.0
# 2                 flexible     Private room  ...        $124             3.0
# 3                 moderate  Entire home/apt  ...         $74            30.0
# 4                 moderate  Entire home/apt  ...         $41            10.0
# ...                    ...              ...  ...          ...            ...
# 102053            moderate     Private room  ...          NaN            7.0
# 102054            flexible     Private room  ...          NaN            1.0
# 102055            moderate  Entire home/apt  ...          NaN            2.0
# 102056              strict     Private room  ...          NaN            2.0
# 102057            flexible  Entire home/apt  ...          NaN            4.0
#
#        number of reviews  last review  reviews per month review rate number  \
# 0                    9.0   10/19/2021               0.21                4.0
# 1                   45.0    5/21/2022               0.38                4.0
# 2                    0.0          NaN                NaN                5.0
# 3                  270.0     7/5/2019               4.64                4.0
# 4                    9.0   11/19/2018               0.10                3.0
# ...                  ...          ...                ...                ...
# 102053              12.0    3/27/2019               0.44                5.0
# 102054              19.0    8/31/2017               0.72                3.0
# 102055              50.0    6/26/2019               3.12                4.0
# 102056               0.0          NaN                NaN                1.0
# 102057              22.0    6/15/2019               0.85                4.0
#
#         calculated host listings count  days_booked  \
# 0                                  6.0        286.0
# 1                                  2.0        228.0
# 2                                  1.0        352.0
# 3                                  1.0        322.0
# 4                                  1.0        289.0
# ...                                ...          ...
# 102053                             1.0          0.0
# 102054                             2.0          0.0
# 102055                             2.0        235.0
# 102056                             1.0          0.0
# 102057                             1.0        238.0
#
#                                               house_rules  license
# 0       Clean up and treat the home the way you'd like...      NaN
# 1       Pet friendly but please confirm with me if the...      NaN
# 2       I encourage you to use my kitchen, cooking and...      NaN
# 3                                                     NaN      NaN
# 4       Please no smoking in the house, porch or on th...      NaN
# ...                                                   ...      ...
# 102053  Shoes off Clean After yourself Turn Lights and...      NaN
# 102054                                             #NAME?      NaN
# 102055  * Check out: 10am * We made an effort to keep ...      NaN
# 102056  Each of us is working and/or going to school a...      NaN
# 102057  Please remember that this is a residential bui...      NaN
#
# [99163 rows x 22 columns]

# %%
## Convierte los títulos de todas las columnas a minúsculas y cambia los espacios que separan palabras por «_».
df.columns=[col.lower().replace(" ","_") for col in df.columns]

# %%
## Elimina el signo de dólares y la coma de las columnas. Convierte las columnas al tipo de dato que les corresponda.
def remove_dollar_sign(value):
    if pd.isna(value):
        return np.NaN
    else:
        return float(value.replace("$","").replace(",","").replace(" ",""))

# %%
df.head()
# Out:
#                                                name host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host_name neighbourhood_group neighbourhood       lat      long  \
# 0  Madaline            Brooklyn    Kensington  40.64749 -73.97237
# 1     Jenna           Manhattan       Midtown  40.75362 -73.98377
# 2     Elise           Manhattan        Harlem  40.80902 -73.94190
# 3     Garry            Brooklyn  Clinton Hill  40.68514 -73.95976
# 4    Lyndon           Manhattan   East Harlem  40.79851 -73.94399
#
#   instant_bookable cancellation_policy        room_type  ...  service_fee  \
# 0            False              strict     Private room  ...        $193
# 1            False            moderate  Entire home/apt  ...         $28
# 2             True            flexible     Private room  ...        $124
# 3             True            moderate  Entire home/apt  ...         $74
# 4            False            moderate  Entire home/apt  ...         $41
#
#   minimum_nights number_of_reviews  last_review  reviews_per_month  \
# 0           10.0               9.0   10/19/2021               0.21
# 1           30.0              45.0    5/21/2022               0.38
# 2            3.0               0.0          NaN                NaN
# 3           30.0             270.0     7/5/2019               4.64
# 4           10.0               9.0   11/19/2018               0.10
#
#   review_rate_number  calculated_host_listings_count  availability_365  \
# 0                4.0                             6.0             286.0
# 1                4.0                             2.0             228.0
# 2                5.0                             1.0             352.0
# 3                4.0                             1.0             322.0
# 4                3.0                             1.0             289.0
#
#                                          house_rules  license
# 0  Clean up and treat the home the way you'd like...      NaN
# 1  Pet friendly but please confirm with me if the...      NaN
# 2  I encourage you to use my kitchen, cooking and...      NaN
# 3                                                NaN      NaN
# 4  Please no smoking in the house, porch or on th...      NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Tarea 4: Análisis exploratorio de los datos.
#
# * Enumera el recuento de los distintos tipos de habitaciones <i>(room type)</i> disponibles en Airbnb.
# * ¿Qué tipo de habitación se adhiere a una política de cancelación <i>(cancellation_policy)</i> más estricta?
# * Enumera los precios por conjunto de barrios <i>(neighborhood group)</i> y menciona cuál es el conjunto de barrios con alquileres más caros.

# %%
## Enumera el recuento de los distintos tipos de habitaciones disponibles en Airbnb.
df.groupby("room_type")["minimum_nights"].count()
# Out:
# room_type
# Entire home/apt    51784
# Hotel room           113
# Private room       44721
# Shared room         2147
# Name: minimum_nights, dtype: int64

# %%
## ¿Qué tipo de habitación se adhiere a una política de cancelación más estricta?
df_cancellation= df[df['cancellation_policy']=='strict']
df_cancellation.groupby("room_type")["name"].count().nlargest(1)
# Out:
# room_type
# Entire home/apt    17190
# Name: name, dtype: int64

# %%
## Enumera los precios por conjunto de barrios y menciona cuál tiene los alquileres más caros.
df_neighborhood = df.groupby("neighbourhood")["price"].count()
print(df_neighborhood)
df_neighborhood.nlargest(1)
# Out:
# neighbourhood
# Allerton             92
# Arden Heights         9
# Arrochar             49
# Arverne             209
# Astoria            1814
#                    ...
# Windsor Terrace     316
# Woodhaven           185
# Woodlawn             27
# Woodrow               3
# Woodside            565
# Name: price, Length: 224, dtype: int64
# neighbourhood
# Bedford-Stuyvesant    7668
# Name: price, dtype: int64

# %% [markdown]
# ## Tarea 5a: Visualización de los datos:
# * Utiliza un histograma horizontal para mostrar los 10 barrios principales en forma ascendente según su precio, ¿cuál es el barrio más barato?
# * Utiliza un histograma horizontal para visualizar los vecindarios que ofrecen alquileres a corto plazo dentro de los próximos 10 días.
# * Utiliza un histograma para enumerar los precios según el tipo de habitación e indica tus conclusiones.
# * Crea un gráfico sectorial para mostrar la distribución de los días reservados por cada conjunto de barrios, ¿qué barrio tiene el mayor porcentaje de reservaciones?

# %% [markdown]
# Utiliza un histograma horizontal para enumera los 10 barrios principales en forma ascendente según su precio.
#
# Utilizo Tableau para el histograma. Neighbourhood en colunmas y convierto price a medida.
# Organizo de menor a mayor y filtro para obtener los últimos 10 elementos

# %% [markdown]
# ![Barrios%20principales.JPG](attachment:Barrios%20principales.JPG)

# %%
## Utiliza un histograma para visualizar los vecindarios que ofrecen alquileres a corto plazo dentro de los próximos 10 días.

# %% [markdown]
# Filtro por instant bookable, minimo del negativo de availability y maximo de noches mínimas. El grafico muesstra el recuento del negativo de availability.

# %% [markdown]
# ![Disponibilidad.JPG](attachment:Disponibilidad.JPG)

# %%
## Utiliza un histograma para enumerar los precios según el tipo de habitación e indica tus conclusiones.

# %% [markdown]
# Utilizo como valores de medidas el maximo, minimo y promedio del precio.
# Muestra que a pesar del tipo de habitacion los precios son muy constantes, que el promedio minimo de habitacionde hotal es superior a la media, pero el promedio maximo de estos esta levemente por debajo de la media maxima de otros tipos de habitación.

# %% [markdown]
# ![Precio%20habitacion.JPG](attachment:Precio%20habitacion.JPG)

# %%
## Crea un gráfico sectorial para mostrar la distribución de los días reservados en cada barrio.
##  ¿Cuál tiene el mayor porcentaje de reservaciones?.

# %% [markdown]
# Se filtro para mostrarse solo los barrios que tengan una disponibilidad menor a 50 dias disponibles en el año.
# El barrio con mayor porcentaje de reservaciones es Bay Terrace.

# %% [markdown]
# ![porcentajes2.JPG](attachment:porcentajes2.JPG)

# %% [markdown]
# ## Tarea 5b: Visualización de los datos.
#
# * ¿El precio del servicio y el precio de la habitación se influyen mutuamente? Ilustra esta relación
# con un gráfico de dispersión e indica tus conclusiones.
# * Utiliza un gráfico de líneas para mostrar en qué año tuvo lugar la máxima construcción de habitaciones.

# %%
##¿El precio del servicio y el precio de la habitación se influyen mutuamente?
## Ilustra esta relación con un gráfico de dispersión e indica tus conclusiones.

# %% [markdown]
# El gráfico muestra que hay poca dispersion en la comparativa del precio-servicio.

# %% [markdown]
# ![precio%20servicio%20y%20habitacion.JPG](attachment:precio%20servicio%20y%20habitacion.JPG)

# %%
## Crea un gráfico de líneas que muestre la cantidad total de anuncios (listings) 
# por cada año de construcción (Construction year).

# %% [markdown]
# En el grafico vemos con claridad que muchas casas listadas han sido construidas en el 2019.

# %% [markdown]
# ![listing-construccion.JPG](attachment:listing-construccion.JPG)

# %% [markdown]
# ## Tarea 5c: Visualización de los datos
#
# * Utiliza diagramas de caja para ilustrar lo siguiente:
#    * el efecto que las notas de las reseñas tienen sobre el precio y
#    * el efecto que tiene la verificación de la identidad del anfitrión sobre el precio.

# %%
## Diagrama de caja 1: Efecto de las notas de las reseñas sobre el precio.

# %% [markdown]
# El tipo de grafico tal vez no sea el mejor para ver con claridad

# %% [markdown]
# ![verificados2.JPG](attachment:verificados2.JPG)

# %%
##  Crea una visualización para comparar, al menos, 
## dos variables diferentes entre los anfitriones verificados y los anfitriones no verificados (host_id_verified).

# %% [markdown]
# ![verificados.JPG](attachment:verificados.JPG)
